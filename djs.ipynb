# %%
import pandas as pd

# %%
file = pd.read_csv('data_3_hena/PredVarwithTickerVarTrend.csv')

# %%
file.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 Ticker       2015       2016       2017  \
# 0           0             0     PG  -9.323276  10.809451  12.532463
# 1           1             1   VIPS -25.512193 -21.637010   4.363319
# 2           2             2     KR  33.118297 -15.036503 -17.068252
# 3           3             3    RAD   2.752291   4.303799 -75.916870
# 4           4             4    GIS  12.897715  10.693172  -1.162942
#
#         2018        2019    PredVar
# 0   4.975151   40.680273  25.676711
# 1 -56.320000  160.000010  31.182346
# 2  -0.990449    8.690633  23.875975
# 3 -66.666666    0.454550  34.710579
# 4 -31.280412   45.027569  23.757251

# %%
df = file.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# %%
df.head()
# Out:
#   Ticker       2015       2016       2017       2018        2019    PredVar
# 0     PG  -9.323276  10.809451  12.532463   4.975151   40.680273  25.676711
# 1   VIPS -25.512193 -21.637010   4.363319 -56.320000  160.000010  31.182346
# 2     KR  33.118297 -15.036503 -17.068252  -0.990449    8.690633  23.875975
# 3    RAD   2.752291   4.303799 -75.916870 -66.666666    0.454550  34.710579
# 4    GIS  12.897715  10.693172  -1.162942 -31.280412   45.027569  23.757251

# %%
df2 = df.set_index('Ticker')
df2.head()
# Out:
#              2015       2016       2017       2018        2019    PredVar
# Ticker
# PG      -9.323276  10.809451  12.532463   4.975151   40.680273  25.676711
# VIPS   -25.512193 -21.637010   4.363319 -56.320000  160.000010  31.182346
# KR      33.118297 -15.036503 -17.068252  -0.990449    8.690633  23.875975
# RAD      2.752291   4.303799 -75.916870 -66.666666    0.454550  34.710579
# GIS     12.897715  10.693172  -1.162942 -31.280412   45.027569  23.757251

# %%
df3 = df2.drop(columns=['2015', '2016', '2017', '2018', '2019'])
df3.head()
# Out:
#           PredVar
# Ticker
# PG      25.676711
# VIPS    31.182346
# KR      23.875975
# RAD     34.710579
# GIS     23.757251

# %%
html = df3.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>PredVar</th>
#     </tr>
#     <tr>
#       <th>Ticker</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>PG</th>
#       <td>25.676711</td>
#     </tr>
#     <tr>
#       <th>VIPS</th>
#       <td>31.182346</td>
#     </tr>
#     <tr>
#       <th>KR</th>
#       <td>23.875975</td>
#     </tr>
#     <tr>
#       <th>RAD</th>
#       <td>34.710579</td>
#     </tr>
#     <tr>
#       <th>GIS</th>
#       <td>23.757251</td>
#     </tr>
#     <tr>
#       <th>PM</th>
#       <td>25.772139</td>
#     </tr>
#     <tr>
#       <th>KO</th>
#       <td>33.908765</td>
#     </tr>
#     <tr>
#       <th>WMT</th>
#       <td>22.647371</td>
#     </tr>
#     <tr>
#       <th>MDLZ</th>
#       <td>21.018389</td>
#     </tr>
#     <tr>
#       <th>MO</th>
#       <td>13.834825</td>
#     </tr>
#     <tr>
#       <th>ABEV</th>
# ...
